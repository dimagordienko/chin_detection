# %%
# !pip install ultralytics
# !pip install mlflow

# %%
from ultralytics import YOLO
model = YOLO('yolo11s-pose.pt')

result = model.train(data='data.yaml', epochs=200, imgsz=640, batch=12)
# Out:
# objc[10035]: Class AVFFrameReceiver is implemented in both /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/cv2/.dylibs/libavdevice.61.3.100.dylib (0x1061f03a8) and /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/av/.dylibs/libavdevice.62.1.100.dylib (0x10d0503a8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[10035]: Class AVFAudioReceiver is implemented in both /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/cv2/.dylibs/libavdevice.61.3.100.dylib (0x1061f03f8) and /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/av/.dylibs/libavdevice.62.1.100.dylib (0x10d0503f8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# New https://pypi.org/project/ultralytics/8.4.21 available 😃 Update with 'pip install -U ultralytics'
# ...
